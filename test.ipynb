# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, MultiLabelBinarizer

# %%
df = pd.read_csv('data.csv')
df_y = df.pop('Market Category')

# %%
category_list = []
for i in df_y:
    if isinstance(i, str):
        if ',' in i:
            new_list = i.split(',')
            for j in new_list:
                if j in category_list:
                    print(j, 'already found')
                    continue
                else:
                    category_list.append(j)
                    print(j, 'added')
        else:
            if i in category_list:
                print(i, 'already found')
                continue
            else:
                category_list.append(i)
                print(i, 'added')
# Out:
# Factory Tuner added
# Luxury added
# High-Performance added
# Luxury already found
# Performance added
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Performance already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Flex Fuel added
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Hatchback added
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Hybrid added
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Diesel added
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Hatchback already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Exotic added
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# Factory Tuner already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# Factory Tuner already found
# High-Performance already found
# High-Performance already found
# Performance already found
# Performance already found
# Performance already found
# Hatchback already found
# Performance already found
# Performance already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Factory Tuner already found
# Performance already found
# Hatchback already found
# Crossover added
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# Factory Tuner already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Luxury already found
# Exotic already found
# High-Performance already found
# Exotic already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Performance already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Hatchback already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Factory Tuner already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Diesel already found
# Luxury already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Crossover already found
# Hatchback already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Hybrid already found
# Crossover already found
# Luxury already found
# Performance already found
# Hybrid already found
# Crossover already found
# Luxury already found
# Performance already found
# Hybrid already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Hybrid already found
# Hybrid already found
# Hybrid already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Exotic already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Hybrid already found
# Performance already found
# Performance already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Flex Fuel already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Performance already found
# Performance already found
# Performance already found
# Crossover already found
# ...
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Diesel already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Performance already found
# Crossover already found
# Luxury already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Crossover already found
# Luxury already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Hybrid already found
# Crossover already found
# Hybrid already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Crossover already found
# Hybrid already found
# Crossover already found
# Hybrid already found
# Crossover already found
# Crossover already found
# Crossover already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Hatchback already found
# Luxury already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Luxury already found
# Hybrid already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Flex Fuel already found
# Performance already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# Performance already found
# Hatchback already found
# Luxury already found
# Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Factory Tuner already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# High-Performance already found
# Luxury already found
# Performance already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Exotic already found
# Luxury already found
# High-Performance already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Crossover already found
# Hatchback already found
# Luxury already found
# Luxury already found

# %%
df_y.drop(df_y.index[df_y.isna()], inplace=True)

# %%
df_y = df_y.apply(lambda x: (x))

# %%
df_y.head
# Out:
# <bound method NDFrame.head of 0        Factory Tuner,Luxury,High-Performance
# 1                           Luxury,Performance
# 2                      Luxury,High-Performance
# 3                           Luxury,Performance
# 4                                       Luxury
#                          ...
# 11909               Crossover,Hatchback,Luxury
# 11910               Crossover,Hatchback,Luxury
# 11911               Crossover,Hatchback,Luxury
# 11912               Crossover,Hatchback,Luxury
# 11913                                   Luxury
# Name: Market Category, Length: 8172, dtype: object>

# %%
df_y = np.array(df_y).reshape(-1, 1)
category_list = np.array(category_list).reshape(-1, 1)

# %%
category_list.shape
# Out:
# (10, 1)

# %%
OHE = OneHotEncoder(categories=category_list)
df_y_enc = OHE.fit_transform(df_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\ML docs\MLBootCamp\test.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/ML%20docs/MLBootCamp/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> OHE = OneHotEncoder(categories=category_list)
# ----> <a href='vscode-notebook-cell:/d%3A/ML%20docs/MLBootCamp/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df_y_enc = OHE.fit_transform(df_y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_encoders.py:488, in OneHotEncoder.fit_transform(self, X, y)
#     466 """
#     467 Fit OneHotEncoder to X, then transform X.
#     468
#    (...)
#     485     returned.
#     486 """
#     487 self._validate_keywords()
# --> 488 return super().fit_transform(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_encoders.py:461, in OneHotEncoder.fit(self, X, y)
#     443 """
#     444 Fit OneHotEncoder to X.
#     445
#    (...)
#     458     Fitted encoder.
#     459 """
#     460 self._validate_keywords()
# --> 461 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#     462 self.drop_idx_ = self._compute_drop_idx()
#     463 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_encoders.py:82, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite)
#      77 X_list, n_samples, n_features = self._check_X(
#      78     X, force_all_finite=force_all_finite
#      79 )
#      80 self.n_features_in_ = n_features
# ---> 82 if self.categories != "auto":
#      83     if len(self.categories) != n_features:
#      84         raise ValueError(
#      85             "Shape mismatch: if categories is an array,"
#      86             " it has to be of shape (n_features,)."
#      87         )
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(OHE.classes_)
# Out:
# ['Crossover' 'Crossover,Diesel' 'Crossover,Exotic,Luxury,High-Performance'
#  'Crossover,Exotic,Luxury,Performance'
#  'Crossover,Factory Tuner,Luxury,High-Performance'
#  'Crossover,Factory Tuner,Luxury,Performance'
#  'Crossover,Factory Tuner,Performance' 'Crossover,Flex Fuel'
#  'Crossover,Flex Fuel,Luxury' 'Crossover,Flex Fuel,Luxury,Performance'
#  'Crossover,Flex Fuel,Performance' 'Crossover,Hatchback'
#  'Crossover,Hatchback,Factory Tuner,Performance'
#  'Crossover,Hatchback,Luxury' 'Crossover,Hatchback,Performance'
#  'Crossover,Hybrid' 'Crossover,Luxury' 'Crossover,Luxury,Diesel'
#  'Crossover,Luxury,High-Performance' 'Crossover,Luxury,Hybrid'
#  'Crossover,Luxury,Performance' 'Crossover,Luxury,Performance,Hybrid'
#  'Crossover,Performance' 'Diesel' 'Diesel,Luxury'
#  'Exotic,Factory Tuner,High-Performance'
#  'Exotic,Factory Tuner,Luxury,High-Performance'
#  'Exotic,Factory Tuner,Luxury,Performance'
#  'Exotic,Flex Fuel,Factory Tuner,Luxury,High-Performance'
#  'Exotic,Flex Fuel,Luxury,High-Performance' 'Exotic,High-Performance'
#  'Exotic,Luxury' 'Exotic,Luxury,High-Performance'
#  'Exotic,Luxury,High-Performance,Hybrid' 'Exotic,Luxury,Performance'
#  'Exotic,Performance' 'Factory Tuner,High-Performance'
#  'Factory Tuner,Luxury' 'Factory Tuner,Luxury,High-Performance'
#  'Factory Tuner,Luxury,Performance' 'Factory Tuner,Performance'
#  'Flex Fuel' 'Flex Fuel,Diesel'
#  'Flex Fuel,Factory Tuner,Luxury,High-Performance' 'Flex Fuel,Hybrid'
#  'Flex Fuel,Luxury' 'Flex Fuel,Luxury,High-Performance'
#  'Flex Fuel,Luxury,Performance' 'Flex Fuel,Performance'
#  'Flex Fuel,Performance,Hybrid' 'Hatchback' 'Hatchback,Diesel'
#  'Hatchback,Factory Tuner,High-Performance'
#  'Hatchback,Factory Tuner,Luxury,Performance'
#  'Hatchback,Factory Tuner,Performance' 'Hatchback,Flex Fuel'
#  'Hatchback,Hybrid' 'Hatchback,Luxury' 'Hatchback,Luxury,Hybrid'
#  'Hatchback,Luxury,Performance' 'Hatchback,Performance' 'High-Performance'
#  'Hybrid' 'Luxury' 'Luxury,High-Performance'
#  'Luxury,High-Performance,Hybrid' 'Luxury,Hybrid' 'Luxury,Performance'
#  'Luxury,Performance,Hybrid' 'Performance' 'Performance,Hybrid']

# %%
from ast import arg
from numpy import argmax
data = 'hello world'

#defiine the universal value
alphabet = 'abcdefghijklmnopqrstuvwxyz '

#map each character to an integer
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))      #this is for decoding 

#to encode integer
integer_encoded = [char_to_int[char] for char in data]
print(integer_encoded)

#now to OHE
OHEed_list = list()

for value in integer_encoded:
    letter = [0 for _ in range(len(alphabet))]
    letter[value] = 1
    OHEed_list.append(letter)


#to invert encoding
inverted = int_to_char[argmax(OHEed_list[0])]
# Out:
# [7, 4, 11, 11, 14, 26, 22, 14, 17, 11, 3]
# 7
